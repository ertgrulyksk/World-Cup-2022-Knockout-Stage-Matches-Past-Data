# %% [markdown]
# <a href="https://colab.research.google.com/github/ertgrulyksk/World-Cup-2022-Knockout-Stage-Matches-Past-Data/blob/main/World_Cup_2022_Knockout_Stage_Matches_Past_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('international_matches.csv')
display(data[0:3])
print(len(data))
print(data.columns.tolist())
# Out:
#          date home_team  away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia    Uruguay       South America       South America
# 1  1993-08-08    Brazil     Mexico       South America       North America
# 2  1993-08-08   Ecuador  Venezuela       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
#
#    away_team_total_fifa_points  home_team_score  ...  shoot_out  \
# 0                            0                3  ...         No
# 1                            0                1  ...         No
# 2                            0                5  ...         No
#
#   home_team_result home_team_goalkeeper_score away_team_goalkeeper_score  \
# ...

# %%
teams=['Netherlands','USA','Argentina','Australia','France','Poland','England','Senegal','Japan','Croatia','Brazil','South Korea','Morocco','Spain','Portugal','Switzerland']
teams16=[['Netherlands','USA'],['Argentina','Australia'],['France','Poland'],['England','Senegal'],['Japan','Croatia'],['Brazil','South Korea'],['Morocco','Spain'],['Portugal','Switzerland']]
teams8=[['Netherlands','Argentina'],['France','England'],['Croatia','Brazil'],['Morocco','Portugal']]
teams4=[['Argentina','Croatia'],['France','Morocco']]
teams2=[['Argentina','France'],['Croatia','Morocco']]

# %%
selects=[]
for i in range(len(data)):
    if data.loc[i,'home_team'] in teams and data.loc[i,'away_team'] in teams:
        selects+=[i]
print(selects)
# Out:
# [35, 84, 86, 117, 129, 136, 180, 182, 214, 250, 257, 288, 330, 340, 347, 361, 389, 419, 424, 428, 436, 490, 523, 617, 678, 687, 712, 725, 732, 880, 898, 920, 949, 971, 984, 989, 1021, 1028, 1072, 1130, 1142, 1214, 1260, 1304, 1309, 1317, 1331, 1394, 1522, 1547, 1557, 1576, 1580, 1592, 1593, 1703, 1826, 1968, 2041, 2116, 2117, 2339, 2350, 2365, 2387, 2399, 2523, 2541, 2672, 2784, 2798, 2834, 2885, 2896, 2911, 2958, 2985, 2987, 2999, 3037, 3044, 3072, 3089, 3094, 3103, 3123, 3137, 3143, 3147, 3148, 3152, 3153, 3239, 3400, 3452, 3489, 3497, 3575, 3597, 3603, 3649, 3660, 3701, 3734, 3759, 3761, 3824, 3852, 3897, 3912, 3934, 3952, 3988, 4040, 4049, 4060, 4062, 4105, 4148, 4263, 4264, 4266, 4560, 4566, 4609, 4613, 4619, 4648, 4684, 4701, 4704, 4783, 4859, 4986, 5072, 5231, 5254, 5268, 5272, 5323, 5374, 5378, 5461, 5476, 5579, 5627, 5652, 5653, 5657, 5660, 5727, 5797, 5804, 5856, 5907, 5990, 6181, 6185, 6237, 6238, 6277, 6324, 6341, 6357, 6362, 6374, 6391, 6400, 6522, 6661, 6787, 6798, 6802
# ...

# %%
data2=data.iloc[selects].reset_index(drop=True)
data2=data2.iloc[:,[0,1,2,9,10,11]]
display(data2)
print(data2.columns.tolist())
col0=data2.columns.tolist()
# Out:
#            date    home_team    away_team  home_team_score  away_team_score  \
# 0    1993-09-08      England       Poland                3                0
# 1    1993-10-13  Netherlands      England                2                0
# 2    1993-10-13     Portugal  Switzerland                1                0
# 3    1993-10-31    Australia    Argentina                1                1
# 4    1993-11-17    Argentina    Australia                1                0
# ..          ...          ...          ...              ...              ...
# 500  2022-06-06        Japan       Brazil                0                1
# 501  2022-06-09  Switzerland        Spain                0                1
# 502  2022-06-11  Netherlands       Poland                2                2
# 503  2022-06-12  Switzerland     Portugal                1                0
# 504  2022-06-13       France      Croatia                0                1
#
#                        tournament
# ...

# %%
# Final & Third-Place Playoff Past Match Results
for i in range(2):
    T=teams2[i]    
    print(T)
    datai=pd.DataFrame(columns=col0)
    for j in range(len(data2)):
        if set(data2.iloc[j,1:3])==set(T):
            datai=pd.concat([datai,data2.iloc[j:j+1]],axis=0)
    if len(datai)>0:
        datai=datai.sort_values('date',ascending=True)
    display(datai)
    print()
# Out:
# ['Argentina', 'France']
#            date home_team  away_team home_team_score away_team_score  \
# 249  2007-02-07    France  Argentina               0               1
# 279  2009-02-11    France  Argentina               0               2
# 440  2018-06-30    France  Argentina               4               3
#
#          tournament
# 249        Friendly
# 279        Friendly
# 440  FIFA World Cup
# ['Croatia', 'Morocco']
#           date home_team away_team home_team_score away_team_score  \
# 57  1996-12-11   Morocco   Croatia               2               2
#
#                    tournament
# 57  King Hassan II Tournament

# %%
# Semifinals Past Match Results
for i in range(2):
    T=teams4[i]
    print(T)
    datai=pd.DataFrame(columns=col0)
    for j in range(len(data2)):
        if set(data2.iloc[j,1:3])==set(T):
            datai=pd.concat([datai,data2.iloc[j:j+1]],axis=0)
    if len(datai)>0:
        datai=datai.sort_values('date',ascending=True)
    display(datai)
    print()
# Out:
# ['Argentina', 'Croatia']
#            date  home_team  away_team home_team_score away_team_score  \
# 15   1994-06-04    Croatia  Argentina               0               0
# 85   1998-06-26  Argentina    Croatia               1               0
# 222  2006-03-01  Argentina    Croatia               2               3
# 383  2014-11-12  Argentina    Croatia               2               1
# 436  2018-06-21  Argentina    Croatia               0               3
#
#          tournament
# 15         Friendly
# 85   FIFA World Cup
# 222        Friendly
# 383        Friendly
# 436  FIFA World Cup
# ['France', 'Morocco']
#            date home_team away_team home_team_score away_team_score  \
# 80   1998-05-29   Morocco    France               2               2
# 94   1999-01-20    France   Morocco               1               0
# 126  2000-06-06   Morocco    France               1               5
# 261  2007-11-16    France   Morocco               2               2
#
# ...

# %%
# Quarterfinals Past Match Results
for i in range(4):
    T=teams8[i]
    print(T)
    datai=pd.DataFrame(columns=col0)
    for j in range(len(data2)):
        if set(data2.iloc[j,1:3])==set(T):
            datai=pd.concat([datai,data2.iloc[j:j+1]],axis=0)
    if len(datai)>0:
        datai=datai.sort_values('date',ascending=True)
    display(datai)
    print()
# Out:
# ['Netherlands', 'Argentina']
#            date    home_team  away_team home_team_score away_team_score  \
# 87   1998-07-04  Netherlands  Argentina               2               1
# 99   1999-03-31  Netherlands  Argentina               1               1
# 174  2003-02-12  Netherlands  Argentina               1               0
# 233  2006-06-21  Netherlands  Argentina               0               0
# 376  2014-07-09  Netherlands  Argentina               0               0
#
#          tournament
# 87   FIFA World Cup
# 99         Friendly
# 174        Friendly
# 233  FIFA World Cup
# 376  FIFA World Cup
# ['France', 'England']
#            date home_team away_team home_team_score away_team_score  \
# 63   1997-06-07    France   England               0               1
# 95   1999-02-10   England    France               0               2
# 132  2000-09-02    France   England               1               1
# 194  2004-06-13    France   England               2               1
# ...

# %%
# Round of 16 Past Match Results
for i in range(8):
    T=teams16[i]
    print(T)
    datai=pd.DataFrame(columns=col0)
    for j in range(len(data2)):
        if set(data2.iloc[j,1:3])==set(T):
            datai=pd.concat([datai,data2.iloc[j:j+1]],axis=0)
    if len(datai)>0:
        datai=datai.sort_values('date',ascending=True)
    display(datai)
    print()
# Out:
# ['Netherlands', 'USA']
#            date    home_team    away_team home_team_score away_team_score  \
# 74   1998-02-21          USA  Netherlands               0               2
# 161  2002-05-19          USA  Netherlands               0               2
# 186  2004-02-18  Netherlands          USA               1               0
# 294  2010-03-03  Netherlands          USA               2               1
# 389  2015-06-05  Netherlands          USA               3               4
#
#     tournament
# 74    Friendly
# 161   Friendly
# 186   Friendly
# 294   Friendly
# 389   Friendly
# ['Argentina', 'Australia']
#            date  home_team  away_team home_team_score away_team_score  \
# 3    1993-10-31  Australia  Argentina               1               1
# 4    1993-11-17  Argentina  Australia               1               0
# 32   1995-06-30  Argentina  Australia               2               0
# 213  2005-06-18  Australia  Argentina               2               4
# ...
